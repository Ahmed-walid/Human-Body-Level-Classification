# %% [markdown]
# # Exploratory Data Anaylsis

# %%
import pandas as pd
import numpy as np
import importlib
import sys
print(sys.path)
importlib.reload(sys.modules['Visualize'])
from Visualize import basic_info, features_info, plot_feature_histograms, plot_violin_plots,\
    visualize_continuous_data, convey_insights, correlation_matrix
# Out:
# ['d:\\Faculty\\Fourth Year\\Second Semster\\Machine Learning\\Project\\Human-Body-Level-Classification\\src\\DataAnalysis', 'c:\\Python39\\python39.zip', 'c:\\Python39\\DLLs', 'c:\\Python39\\lib', 'c:\\Python39', '', 'C:\\Users\\Moham\\AppData\\Roaming\\Python\\Python39\\site-packages', 'c:\\Python39\\lib\\site-packages', 'c:\\Python39\\lib\\site-packages\\win32', 'c:\\Python39\\lib\\site-packages\\win32\\lib', 'c:\\Python39\\lib\\site-packages\\Pythonwin', 'src/DataAnalysis', 'src/DataAnalysis']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 7
#       5 print(sys.path)
#       6 sys.path.append('src/DataAnalysis')
# ----> 7 importlib.reload(sys.modules['Visualize'])
#       8 from Visualize import basic_info, features_info, plot_feature_histograms, plot_violin_plots,\
#       9     visualize_continuous_data, convey_insights, correlation_matrix
#
# KeyError: 'Visualize'

# %% [markdown]
# ### Reading the data

# %%
DATASET_DIR = '../../Dataset/body_level_classification_train.csv'
df = pd.read_csv(DATASET_DIR)

# %% [markdown]
# ### Small Sample

# %%
df.head()
# Out:
#    Gender        Age    Height     Weight H_Cal_Consump  Veg_Consump  \
# 0  Female  22.547298  1.722461  51.881263           yes     2.663421
# 1    Male  19.799054  1.743702  54.927529           yes     2.000000
# 2  Female  17.823438  1.708406  50.000000           yes     1.642241
# 3  Female  19.007177  1.690727  49.895716           yes     1.212908
# 4    Male  19.729250  1.793315  58.195150           yes     2.508835
#
#    Water_Consump Alcohol_Consump Smoking  Meal_Count Food_Between_Meals  \
# 0       1.041110              no      no    3.000000         Frequently
# 1       2.847264       Sometimes      no    3.289260          Sometimes
# 2       1.099231       Sometimes      no    3.452590          Sometimes
# 3       1.029703       Sometimes      no    3.207071          Sometimes
# 4       2.076933              no      no    3.435905          Sometimes
#
#   Fam_Hist H_Cal_Burn  Phys_Act  Time_E_Dev              Transport  \
# 0      yes         no  0.794402    1.391948  Public_Transportation
# 1      yes         no  1.680844    2.000000  Public_Transportation
# 2       no         no  0.418875    1.000000  Public_Transportation
# 3       no         no  2.000000    1.000000  Public_Transportation
# 4      yes         no  2.026668    1.443328             Automobile
#
#      Body_Level
# 0  Body Level 1
# 1  Body Level 1
# 2  Body Level 1
# 3  Body Level 1
# 4  Body Level 1

# %% [markdown]
# ### Basic Information

# %%
basic_info(df)
# Out:
# <h2 style="text-align:left;">Basic Counts</h2><table style="width:50%; border-collapse: collapse; font-size: 16px; text-align:center; padding: 10px; border: 1px solid #fff;"><tr><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Number of samples</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Number of features</td></tr><tr><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">1477</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">17</td></tr>

# %% [markdown]
# ### Features Information

# %%
features_info(df)
# Out:
# <h2 style="text-align:left;">Features Types, Uniques Count, Missing Ratio, Outlier Ratio</h2><table style="width:50%; border-collapse: collapse; font-size: 16px; text-align:center; padding: 10px; border: 1px solid #fff;"><tr><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Gender</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Age</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Height</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Weight</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">H_Cal_Consump</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Veg_Consump</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Water_Consump</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Alcohol_Consump</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Smoking</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Meal_Count</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Food_Between_Meals</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Fam_Hist</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">H_Cal_Burn</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Phys_Act</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Time_E_Dev</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Transport</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; border-right: 1px solid #fff;">Body_Level</td></tr><tr><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Binary</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Numerical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Numerical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Numerical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Binary</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Numerical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Numerical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Categorical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Binary</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Numerical</td><td style="border: 1px solid #fff; text-align:center; padding: 10px; color: white; opacity: 0.8; border-left: 1px solid #fff;">Categorical</td><td style="border: 1px solid #fff; ...

# %% [markdown]
# ### Variables Histograms

# %%
plot_feature_histograms(df, sample_size=100)
# Out:
# 17it [00:00, 34.26it/s]

# %% [markdown]
# ### Numerical Variables Statistics

# %%
df.describe()
# Out:
#                Age       Height       Weight  Veg_Consump  Water_Consump  \
# count  1477.000000  1477.000000  1477.000000  1477.000000    1477.000000
# mean     24.290420     1.701602    86.542290     2.421912       2.005120
# std       6.323081     0.094654    26.278277     0.540711       0.620307
# min      15.000000     1.456346    39.000000     1.000000       1.000000
# 25%      19.895877     1.629194    65.000000     2.000000       1.549931
# 50%      22.720449     1.701284    82.636162     2.416044       2.000000
# 75%      26.000000     1.770278   106.690530     3.000000       2.482933
# max      55.246250     1.980000   173.000000     3.000000       3.000000
#
#         Meal_Count     Phys_Act   Time_E_Dev
# count  1477.000000  1477.000000  1477.000000
# mean      2.682104     1.023106     0.650672
# std       0.790751     0.844840     0.605199
# min       1.000000     0.000000     0.000000
# 25%       2.644692     0.145687     0.000000
# 50%       3.000000     1.000000     0.616045
# 75%       3.000000     1.672639     1.000000
# max       4.000000     3.000000     2.000000

# %% [markdown]
# ### Visualize Continuous Variables

# %%
visualize_continuous_data(df, sample_size=1477)
# Out:
# Number of continuous features: 8
# 28it [00:00, 866.32it/s]

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix(df, sample_size=1477)
